# %%
import pyttsx3
import datetime
import time
import speech_recognition as sr

# %%
def initialize_engine():
    engine = pyttsx3.init('sapi5')
    voices = engine.getProperty('voices')
    engine.setProperty('voice', voices[1].id)
    rate = engine.getProperty('rate')
    engine.setProperty('rate', rate - 50)
    volume = engine.getProperty('volume')
    engine.setProperty('volume', volume + 0.25)
    return engine

# %%
engine = initialize_engine()
def speak(text):
    engine.say(text)
    engine.runAndWait()

# %%
def command():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...",end="",flush=True)
        r.adjust_for_ambient_noise(source, duration=0.5)
        audio = r.listen(source, phrase_time_limit=8)

    try:
        print("Recognizing...",end="",flush=True)
        query = r.recognize_google(audio, language='en-in')
        print(f"User said: {query}")
        return query
    except sr.UnknownValueError:
        return None
    except sr.RequestError:
        speak("Speech service is down.")
        return None

# %%
while True:
    query = command()
    if not query:
        speak("I didn't catch that.")
        continue

    query = query.lower()
    print(f"Processing command: {query}")
# Out:
# Listening...Recognizing...Listening...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 2
#       1 while True:
# ----> 2     query = command()
#       3     if not query:
#       4         speak("I didn't catch that.")
#
# Cell In[47], line 6, in command()
#       4     print("Listening...",end="",flush=True)
#       5     r.adjust_for_ambient_noise(source, duration=0.5)
# ----> 6     audio = r.listen(source, phrase_time_limit=8)
#       8 try:
#       9     print("Recognizing...",end="",flush=True)
#
# File c:\A_Computer_Main\main\all_work\vs-studio-saves\virtual_environment\lib\site-packages\speech_recognition\__init__.py:461, in Recognizer.listen(self, source, timeout, phrase_time_limit, snowboy_configuration, stream)
#     459 result = self._listen(source, timeout, phrase_time_limit, snowboy_configuration, stream)
#     460 if not stream:
# --> 461     for a in result:
#     462         return a
#     463 return result
#
# File c:\A_Computer_Main\main\all_work\vs-studio-saves\virtual_environment\lib\site-packages\speech_recognition\__init__.py:531, in Recognizer._listen(self, source, timeout, phrase_time_limit, snowboy_configuration, stream)
#     528 if phrase_time_limit and elapsed_time - phrase_start_time > phrase_time_limit:
#     529     break
# --> 531 buffer = source.stream.read(source.CHUNK)
#     532 if len(buffer) == 0: break  # reached end of the stream
#     533 frames.append(buffer)
#
# File c:\A_Computer_Main\main\all_work\vs-studio-saves\virtual_environment\lib\site-packages\speech_recognition\__init__.py:192, in Microphone.MicrophoneStream.read(self, size)
#     191 def read(self, size):
# --> 192     return self.pyaudio_stream.read(size, exception_on_overflow=False)
#
# File c:\A_Computer_Main\main\all_work\vs-studio-saves\virtual_environment\lib\site-packages\pyaudio\__init__.py:570, in PyAudio.Stream.read(self, num_frames, exception_on_overflow)
#     567 if not self._is_input:
#     568     raise IOError("Not input stream",
#     569                   paCanNotReadFromAnOutputOnlyStream)
# --> 570 return pa.read_stream(self._stream, num_frames,
#     571                       exception_on_overflow)
#
# KeyboardInterrupt:

# %%
import datetime


def cal_day():
    day  = datetime.datetime.today().weekday() + 1
    day_dict = {1: 'Monday', 2: 'Tuesday', 3: 'Wednesday', 4: 'Thursday',
                5: 'Friday', 6: 'Saturday', 7: 'Sunday'}
    if day in day_dict:
        day_of_week = day_dict[day]
        # print(f"Today is {day_of_week}.")
        speak(f"Today is {day_of_week}.")

    return day_of_week

# %%
def wishme():
    hour = int(datetime.datetime.now().hour)
    if 0 <= hour < 12:
        speak("Good Morning!")
    elif 12 <= hour < 18:
        speak("Good Afternoon!")
    else:
        speak("Good Evening!")
    t = time.strftime("%I:%M %p")
    day = cal_day()
    print(f"It's {t} on {day}. How can I assist you?")
    speak(f"It's {t} on {day}. How can I assist you?")

# %%
wishme()
# Out:
# It's 10:44 PM on Tuesday. How can I assist you?
